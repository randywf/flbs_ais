# %% [markdown]
# # Asian Carp
# #### *Cyprinus carpio*
# ---

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

import numpy as np
import pandas as pd

import flbs_ais.nas as nas

# %% [markdown]
# #### Database Species Search Results

# %%
search_result = nas.species_search('Cyprinus', 'carpio')
search_string = nas.species_string(search_result)
print(search_string)
# Out:
# speciesID: 4
# itis_tsn: 163344
# group: Fishes
# family: Cyprinidae
# genus: Cyprinus
# species: carpio
# subspecies:
# variety:
# authority: Linnaeus, 1758
# common_name: Common Carp
# native_exotic: Exotic
# Fresh/Marine/Brackish: Freshwater

# %% [markdown]
# ---
# ## API Query Dataframe for Asian Carp
# There seems to be an error in the json file when retrieving more than 2,347 results.

# %%
api_key = ""
with open("../tmp/api_key.txt", 'r') as file:
    api_key = file.readline()
api_df = nas.getdf(4, keep_columns=None, limit=2347, api_key=api_key)
print(f"Results: {len(api_df)}")
api_df.head()
# Out:
# Results: 2347
#    specimennumber  speciesid   group      family     genus species  \
# 0           26225          4  Fishes  Cyprinidae  Cyprinus  carpio
# 1           26265          4  Fishes  Cyprinidae  Cyprinus  carpio
# 2           26284          4  Fishes  Cyprinidae  Cyprinus  carpio
# 3           26289          4  Fishes  Cyprinidae  Cyprinus  carpio
# 4           26296          4  Fishes  Cyprinidae  Cyprinus  carpio
#
#     scientificname   commonname  country    state  ...  year month  day  \
# 0  Cyprinus carpio  Common Carp      NaN  Alabama  ...  1988   NaN  NaN
# 1  Cyprinus carpio  Common Carp      NaN  Alabama  ...  1968   NaN  NaN
# 2  Cyprinus carpio  Common Carp      NaN  Alabama  ...  1998   NaN  NaN
# 3  Cyprinus carpio  Common Carp      NaN  Alabama  ...  1971   NaN  NaN
# 4  Cyprinus carpio  Common Carp      NaN  Alabama  ...  1998   NaN  NaN
#
#         status comments              recordtype  disposal museumcatnumber  \
# 0  established           Personal communication
# 1  established                       Literature
# 2  established                       Literature
# 3  established                       Literature
# 4  established                       Literature
#
#   freshmarineintro                                         references
# 0       Freshwater                                                 []
# 1       Freshwater  [{'key': 78, 'refType': 'Book', 'year': 1968, ...
# 2       Freshwater  [{'key': 1885, 'refType': 'Conference Proceedi...
# 3       Freshwater  [{'key': 90, 'refType': 'Journal Article', 'ye...
# 4       Freshwater  [{'key': 1885, 'refType': 'Conference Proceedi...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Most Common References for API Query Dataframe

# %%
api_ref_count = nas.ref_counts(api_df)
print(nas.ref_string(api_ref_count, limit=5))
# Out:
# --------
# Most common reference 1
#
# Total Occurrences:  352
# --------
#
# --------
# Most common reference 2
#
# Source number:      1
# Title:              Common Carp - Cyprinus carpio. Montana Field Guide.
# Author:             Montana Natural Heritage Program and Montana Fish, Wildlife and Parks.
# Publisher:          mtgov.
# Publisher Location:
# Year:               2009
# Reference Type:     Database
#
# Source number:      2
# Title:              Natural Heritage Tracker - Common Carp (Cyprinus carpio).
# Author:             Montana Natural Heritage Program.
# Publisher:          mtgov.
# Publisher Location:
# Year:               2009
# Reference Type:     Database
#
# Total Occurrences:  201
# --------
#
# --------
# Most common reference 3
#
# Source number:      1
# Title:              Illinois Natural History Survey Fish Collection Database Search Results.
# Author:             Illinois Natural History Survey.
# Publisher:          Illinois Natural History Survey.
# Publisher Location:
# Year:               2004
# Reference Type:     Database
#
# Total Occurrences:  171
# --------
#
# --------
# Most common reference 4
#
# Source number:      1
# Title:              Fishes of Arkansas.
# Author:             Robison, H.W., and T.M. Buchanan.
# Publisher:          University of Arkansas Press
# Publisher Location: Fayetteville, AR
# Year:               1988
# Reference Type:     Book
#
# Total Occurrences:  129
# --------
#
# --------
# Most common reference 5
#
# Source number:      1
# Title:              Fish Records: Water Body - All Tackle.
# Author:             Texas Parks and Wildlife Department.
# Publisher:          Texas Parks and Wildlife Department.
# Publisher Location:
# Year:               2001
# Reference Type:     Web Page
#
# Total Occurrences:  67
# --------

# %% [markdown]
# ---
# ## CSV File Dataframe for Asian Carp

# %%
csv_df = nas.process_csv_df("../tmp/NAS-Data-AsianCarp.csv")
print(f"Results: {len(csv_df)}")
csv_df.head()
# Out:
# Results: 46342
#    specimennumber  speciesid   group      family  genus  species  \
# 0         1565260          4  Fishes  Cyprinidae    NaN      NaN
# 1         1565261          4  Fishes  Cyprinidae    NaN      NaN
# 2         1566349          4  Fishes  Cyprinidae    NaN      NaN
# 3         1566524          4  Fishes  Cyprinidae    NaN      NaN
# 4         1570429          4  Fishes  Cyprinidae    NaN      NaN
#
#     scientificname   commonname country state  ...  year month   day  \
# 0  Cyprinus carpio  Common Carp  Canada   ONT  ...  2014   8.0  13.0
# 1  Cyprinus carpio  Common Carp  Canada   ONT  ...  2014   8.0  13.0
# 2  Cyprinus carpio  Common Carp  Canada   ONT  ...  2016   8.0  17.0
# 3  Cyprinus carpio  Common Carp  Canada   ONT  ...  2016   8.0  29.0
# 4  Cyprinus carpio  Common Carp  Canada   ONT  ...  2016   8.0   6.0
#
#         status                                           comments  recordtype  \
# 0  established  <a href = http://www.misin.msu.edu/browse/reco...  Literature
# 1  established  <a href = http://www.misin.msu.edu/browse/reco...  Literature
# 2  established  <a href = http://www.misin.msu.edu/browse/reco...  Literature
# 3  established  <a href = http://www.misin.msu.edu/browse/reco...  Literature
# 4  established  <a href = http://www.misin.msu.edu/browse/reco...  Literature
#
#   disposal  museumcatnumber  freshmarineintro  \
# 0      NaN              NaN        Freshwater
# 1      NaN              NaN        Freshwater
# 2      NaN              NaN        Freshwater
# 3      NaN              NaN        Freshwater
# 4      NaN              NaN        Freshwater
#
#                                           references
# 0  [{'key': 27950, 'refType': 'Database', 'year':...
# 1  [{'key': 27950, 'refType': 'Database', 'year':...
# 2  [{'key': 27950, 'refType': 'Database', 'year':...
# 3  [{'key': 27950, 'refType': 'Database', 'year':...
# 4  [{'key': 27950, 'refType': 'Database', 'year':...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Most Common References for CSV File Dataframe

# %%
csv_ref_count = nas.ref_counts(csv_df)
print(nas.ref_string(csv_ref_count, limit=20))
# Out:
# --------
# Most common reference 1
#
# Source number:      1
# Title:              Mississippi River Long Term Resource Monitoring Program.
# Author:             U.S. Geological Survey
# Publisher:          U.S. Geological Survey
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Total Occurrences:  15282
# --------
#
# --------
# Most common reference 2
#
# Source number:      1
# Title:              Wisconsin Center for Integrated Data Analytics (CIDA) fish dataset
# Author:             Wisconsin Department of Natural Resources
# Publisher:          Wisconsin Department of Natural Resources
# Publisher Location: Madison, WI
# Year:               2014
# Reference Type:     Database
#
# Total Occurrences:  7006
# --------
#
# --------
# Most common reference 3
#
# Source number:      1
# Title:              Pennsylvania&#39;s Field Guide to Aquatic Invasive Species.
# Author:             Pennsylvania Sea Grant.
# Publisher:          Pennsylvania Sea Grant
# Publisher Location: nan
# Year:               2013
# Reference Type:     Book
#
# Total Occurrences:  5967
# --------
#
# --------
# Most common reference 4
#
# Source number:      1
# Title:              Multi State Aquatic Resources Information System (MARIS) Master Database records via Biodiversity Information Serving Our Nation (BISON)
# Author:             Loftus, A.
# Publisher:          nan
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Source number:      2
# Title:              Minnesota DNR Statewide Stream Survey via MARIS
# Author:             Minnesota Department of Natural Resources
# Publisher:          Minnesota Department of Natural Resources
# Publisher Location: St. Paul, MN
# Year:               2009
# Reference Type:     Database
#
# Total Occurrences:  3586
# --------
#
# --------
# Most common reference 5
#
# Source number:      1
# Title:              Multi State Aquatic Resources Information System (MARIS) Master Database records via Biodiversity Information Serving Our Nation (BISON)
# Author:             Loftus, A.
# Publisher:          nan
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Source number:      2
# Title:              Pennsylvania Freshwater Fisheries Database via MARIS
# Author:             Pennsylvania Fish and Boat Commission
# Publisher:          Pennsylvania Fish and Boat Commission
# Publisher Location: nan
# Year:               2007
# Reference Type:     Database
#
# Total Occurrences:  1674
# --------
#
# --------
# Most common reference 6
#
# Source number:      1
# Title:              Exotic fish distributions in Nebraska.
# Author:             Schainost, S.
# Publisher:          nan
# Publisher Location: nan
# Year:               2005
# Reference Type:     Database
#
# Total Occurrences:  1384
# --------
#
# --------
# Most common reference 7
#
# Source number:      1
# Title:              Multi State Aquatic Resources Information System (MARIS) Master Database records via Biodiversity Information Serving Our Nation (BISON)
# Author:             Loftus, A.
# Publisher:          nan
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Source number:      2
# Title:              Georgia Annual Standardized Reservoir Sampling data via MARIS
# Author:             Georgia Department of Environmental Resources.
# Publisher:          Georgia Department of Natural Resources
# Publisher Location: nan
# Year:               2010
# Reference Type:     Database
#
# Total Occurrences:  1165
# --------
#
# --------
# Most common reference 8
#
# Source number:      1
# Title:              Multi State Aquatic Resources Information System (MARIS) Master Database records via Biodiversity Information Serving Our Nation (BISON)
# Author:             Loftus, A.
# Publisher:          nan
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Source number:      2
# Title:              Wisconsin Statewide Fisheries Database via MARIS
# Author:             Wisconsin Department of Natural Resources (WIDNR)
# Publisher:          Wisconsin Department of Natural Resources
# Publisher Location: nan
# Year:               2008
# Reference Type:     Database
#
# Total Occurrences:  1023
# --------
#
# --------
# Most common reference 9
#
# Source number:      1
# Title:              Nonindigenous Fishes in the Upper Illinois River Basin Waterways (2013-2018)
# Author:             Belcik, J.T.
# Publisher:          U.S. Army Corps of Engineers
# Publisher Location: Chicago, IL
# Year:               2018
# Reference Type:     Database
#
# Total Occurrences:  834
# --------
#
# --------
# Most common reference 10
#
# Source number:      1
# Title:              Multi State Aquatic Resources Information System (MARIS) Master Database records via Biodiversity Information Serving Our Nation (BISON)
# Author:             Loftus, A.
# Publisher:          nan
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Source number:      2
# Title:              New York State Freshwater Fisheries Database via MARIS
# Author:             New York State Department of Environmental Conservation (NYDEC)
# Publisher:          New York State Department of Environmental Conservation.
# Publisher Location: Albany, NY
# Year:               2007
# Reference Type:     Database
#
# Total Occurrences:  488
# --------
#
# --------
# Most common reference 11
#
# Source number:      1
# Title:              Multi State Aquatic Resources Information System (MARIS) Master Database records via Biodiversity Information Serving Our Nation (BISON)
# Author:             Loftus, A.
# Publisher:          nan
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Source number:      2
# Title:              Wyoming Freshwater Fisheries Database via MARIS
# Author:             Wyoming Game and Fish Department.
# Publisher:          Wyoming Game and Fish Department
# Publisher Location: nan
# Year:               2008
# Reference Type:     Database
#
# Total Occurrences:  427
# --------
#
# --------
# Most common reference 12
#
# Source number:      1
# Title:              New York State Fish Data from Public Waters.
# Author:             New York State Department of Environmental Conservation.
# Publisher:          New York State Department of Environmental Conservation.
# Publisher Location: nan
# Year:               2012
# Reference Type:     Database
#
# Total Occurrences:  423
# --------
#
# --------
# Most common reference 13
#
# Total Occurrences:  413
# --------
#
# --------
# Most common reference 14
#
# Source number:      1
# Title:              Multi State Aquatic Resources Information System (MARIS) Master Database records via Biodiversity Information Serving Our Nation (BISON)
# Author:             Loftus, A.
# Publisher:          nan
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Source number:      2
# Title:              NJDRW Freshwater Fisheries Database via MARIS
# Author:             New Jersey Division of Fish and Wildlife
# Publisher:          New Jersey Division of Fish and Wildlife
# Publisher Location: nan
# Year:               2013
# Reference Type:     Database
#
# Total Occurrences:  382
# --------
#
# --------
# Most common reference 15
#
# Source number:      1
# Title:              Multi State Aquatic Resources Information System (MARIS) Master Database records via Biodiversity Information Serving Our Nation (BISON)
# Author:             Loftus, A.
# Publisher:          nan
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Source number:      2
# Title:              Maryland Department of Natural Resources Inland Fisheries Database via MARIS
# Author:             Maryland Department of Natural Resources.
# Publisher:          Maryland Department of Natural Resources
# Publisher Location: nan
# Year:               2010
# Reference Type:     Database
#
# Total Occurrences:  376
# --------
#
# --------
# Most common reference 16
#
# Source number:      1
# Title:              Global Biodiversity Information Facility (GBIF) Database.
# Author:             GBIF
# Publisher:          Global Biodiversity Information Facility
# Publisher Location: nan
# Year:               2013
# Reference Type:     Database
#
# Source number:      2
# Title:              Sam Noble Oklahoma Museum of Natural History ichthyology collection. Accessed through GBIF data portal,http://www.gbif.org/dataset/71e6db8e-f762-11e1-a439-00145eb45e9a
# Author:             University of Oklahoma
# Publisher:          University of Oklahoma
# Publisher Location: Norman, OK
# Year:               2013
# Reference Type:     Database
#
# Total Occurrences:  370
# --------
#
# --------
# Most common reference 17
#
# Source number:      1
# Title:              Multi State Aquatic Resources Information System (MARIS) Master Database records via Biodiversity Information Serving Our Nation (BISON)
# Author:             Loftus, A.
# Publisher:          nan
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Source number:      2
# Title:              Oklahoma Department of Wildlife Conservation Fisheries Data via MARIS
# Author:             Oklahoma Department of Wildlife Conservation
# Publisher:          Oklahoma Department of Wildlife Conservation
# Publisher Location: nan
# Year:               2010
# Reference Type:     Database
#
# Total Occurrences:  347
# --------
#
# --------
# Most common reference 18
#
# Source number:      1
# Title:              Multi State Aquatic Resources Information System (MARIS) Master Database records via Biodiversity Information Serving Our Nation (BISON)
# Author:             Loftus, A.
# Publisher:          nan
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Source number:      2
# Title:              Michigan DNR Freshwater Fisheries Database via MARIS
# Author:             Michigan Department of Natural Resources (MIDNR).
# Publisher:          Michigan Department of Natural Resources (MIDNR).
# Publisher Location: nan
# Year:               2005
# Reference Type:     Database
#
# Total Occurrences:  261
# --------
#
# --------
# Most common reference 19
#
# Source number:      1
# Title:              Multi State Aquatic Resources Information System (MARIS) Master Database records via Biodiversity Information Serving Our Nation (BISON)
# Author:             Loftus, A.
# Publisher:          nan
# Publisher Location: nan
# Year:               2011
# Reference Type:     Database
#
# Source number:      2
# Title:              Iowa Freshwater Fisheries Database via MARIS
# Author:             Iowa Department of Natural Resources.
# Publisher:          Iowa Department of Natural Resources.
# Publisher Location: nan
# Year:               2005
# Reference Type:     Database
#
# Total Occurrences:  202
# --------
#
# --------
# Most common reference 20
#
# Source number:      1
# Title:              Common Carp - Cyprinus carpio. Montana Field Guide.
# Author:             Montana Natural Heritage Program and Montana Fish, Wildlife and Parks.
# Publisher:          mtgov.
# Publisher Location: nan
# Year:               2009
# Reference Type:     Database
#
# Source number:      2
# Title:              Natural Heritage Tracker - Common Carp (Cyprinus carpio).
# Author:             Montana Natural Heritage Program.
# Publisher:          mtgov.
# Publisher Location: nan
# Year:               2009
# Reference Type:     Database
#
# Total Occurrences:  201
# --------
