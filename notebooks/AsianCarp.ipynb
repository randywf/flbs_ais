# %% [markdown]
# # Asian Carp
# #### *Cyprinus carpio*
# ---

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

import numpy as np
import pandas as pd

import flbs_ais.nas as nas

# %% [markdown]
# #### Database Species Search Results
# NOTE: Enter scientific name in the following code block

# %%
search_result = nas.species_search('Cyprinus', 'carpio')
search_string = nas.species_string(search_result)
print(search_string)
# Out:
# speciesID: 4
# itis_tsn: 163344
# group: Fishes
# family: Cyprinidae
# genus: Cyprinus
# species: carpio
# subspecies:
# variety:
# authority: Linnaeus, 1758
# common_name: Common Carp
# native_exotic: Exotic
# Fresh/Marine/Brackish: Freshwater

# %% [markdown]
# ---
# ## API Query Dataframe for Asian Carp
# There seems to be an error in the json file when retrieving more than 2,347 results.

# %%
api_key = ""
with open("../tmp/api_key.txt", 'r') as file:
    api_key = file.readline()
api_df = nas.getdf(4, keep_columns=None, limit=2347, api_key=api_key)
print(f"Results: {len(api_df)}")
api_df.head()
# Out:
# Results: 2347
#    specimennumber  speciesid   group      family     genus species  \
# 0           26225          4  Fishes  Cyprinidae  Cyprinus  carpio
# 1           26265          4  Fishes  Cyprinidae  Cyprinus  carpio
# 2           26284          4  Fishes  Cyprinidae  Cyprinus  carpio
# 3           26289          4  Fishes  Cyprinidae  Cyprinus  carpio
# 4           26296          4  Fishes  Cyprinidae  Cyprinus  carpio
#
#     scientificname   commonname  country    state  ...  year month  day  \
# 0  Cyprinus carpio  Common Carp      NaN  Alabama  ...  1988   NaN  NaN
# 1  Cyprinus carpio  Common Carp      NaN  Alabama  ...  1968   NaN  NaN
# 2  Cyprinus carpio  Common Carp      NaN  Alabama  ...  1998   NaN  NaN
# 3  Cyprinus carpio  Common Carp      NaN  Alabama  ...  1971   NaN  NaN
# 4  Cyprinus carpio  Common Carp      NaN  Alabama  ...  1998   NaN  NaN
#
#         status comments              recordtype  disposal museumcatnumber  \
# 0  established           Personal communication
# 1  established                       Literature
# 2  established                       Literature
# 3  established                       Literature
# 4  established                       Literature
#
#   freshmarineintro                                         references
# 0       Freshwater                                                 []
# 1       Freshwater  [{'key': 78, 'refType': 'Book', 'year': 1968, ...
# 2       Freshwater  [{'key': 1885, 'refType': 'Conference Proceedi...
# 3       Freshwater  [{'key': 90, 'refType': 'Journal Article', 'ye...
# 4       Freshwater  [{'key': 1885, 'refType': 'Conference Proceedi...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Most Common References for API Query Dataframe

# %%
api_ref_count = nas.ref_counts(api_df)
print(nas.ref_string(api_ref_count, limit=5))
# Out:
# --------
# Most common reference 1
#
# Total Occurrences:  352
# --------
#
# --------
# Most common reference 2
#
# Source number:      1
# Title:              Common Carp - Cyprinus carpio. Montana Field Guide.
# Author:             Montana Natural Heritage Program and Montana Fish, Wildlife and Parks.
# Publisher:          mtgov.
# Publisher Location:
# Year:               2009
# Reference Type:     Database
#
# Source number:      2
# Title:              Natural Heritage Tracker - Common Carp (Cyprinus carpio).
# Author:             Montana Natural Heritage Program.
# Publisher:          mtgov.
# Publisher Location:
# Year:               2009
# Reference Type:     Database
#
# Total Occurrences:  201
# --------
#
# --------
# Most common reference 3
#
# Source number:      1
# Title:              Illinois Natural History Survey Fish Collection Database Search Results.
# Author:             Illinois Natural History Survey.
# Publisher:          Illinois Natural History Survey.
# Publisher Location:
# Year:               2004
# Reference Type:     Database
#
# Total Occurrences:  171
# --------
#
# --------
# Most common reference 4
#
# Source number:      1
# Title:              Fishes of Arkansas.
# Author:             Robison, H.W., and T.M. Buchanan.
# Publisher:          University of Arkansas Press
# Publisher Location: Fayetteville, AR
# Year:               1988
# Reference Type:     Book
#
# Total Occurrences:  129
# --------
#
# --------
# Most common reference 5
#
# Source number:      1
# Title:              Fish Records: Water Body - All Tackle.
# Author:             Texas Parks and Wildlife Department.
# Publisher:          Texas Parks and Wildlife Department.
# Publisher Location:
# Year:               2001
# Reference Type:     Web Page
#
# Total Occurrences:  67
# --------

# %% [markdown]
# ---
# ## CSV File Dataframe for Asian Carp

# %%
csv_df = nas.process_csv_df("../tmp/NAS-Data-AsianCarp.csv")
print(f"Results: {len(csv_df)}")
csv_df.head()
# Out:
# Results: 46342
#    specimennumber  speciesid   group      family  genus  species  \
# 0         1565260          4  Fishes  Cyprinidae    NaN      NaN
# 1         1565261          4  Fishes  Cyprinidae    NaN      NaN
# 2         1566349          4  Fishes  Cyprinidae    NaN      NaN
# 3         1566524          4  Fishes  Cyprinidae    NaN      NaN
# 4         1570429          4  Fishes  Cyprinidae    NaN      NaN
#
#     scientificname   commonname country state  ...  year month   day  \
# 0  Cyprinus carpio  Common Carp  Canada   ONT  ...  2014   8.0  13.0
# 1  Cyprinus carpio  Common Carp  Canada   ONT  ...  2014   8.0  13.0
# 2  Cyprinus carpio  Common Carp  Canada   ONT  ...  2016   8.0  17.0
# 3  Cyprinus carpio  Common Carp  Canada   ONT  ...  2016   8.0  29.0
# 4  Cyprinus carpio  Common Carp  Canada   ONT  ...  2016   8.0   6.0
#
#         status                                           comments  recordtype  \
# 0  established  <a href = http://www.misin.msu.edu/browse/reco...  Literature
# 1  established  <a href = http://www.misin.msu.edu/browse/reco...  Literature
# 2  established  <a href = http://www.misin.msu.edu/browse/reco...  Literature
# 3  established  <a href = http://www.misin.msu.edu/browse/reco...  Literature
# 4  established  <a href = http://www.misin.msu.edu/browse/reco...  Literature
#
#   disposal  museumcatnumber  freshmarineintro  \
# 0      NaN              NaN        Freshwater
# 1      NaN              NaN        Freshwater
# 2      NaN              NaN        Freshwater
# 3      NaN              NaN        Freshwater
# 4      NaN              NaN        Freshwater
#
#                                           references
# 0  [{'key': 27950, 'refType': 'Database', 'year':...
# 1  [{'key': 27950, 'refType': 'Database', 'year':...
# 2  [{'key': 27950, 'refType': 'Database', 'year':...
# 3  [{'key': 27950, 'refType': 'Database', 'year':...
# 4  [{'key': 27950, 'refType': 'Database', 'year':...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Most Common References for CSV File Dataframe
# NOTE: Reference information for CSV files is not currently functional

# %%
#csv_ref_count = nas.ref_counts(csv_df)
#print(nas.ref_string(csv_ref_count, limit=20))
