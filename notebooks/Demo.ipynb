# %% [markdown]
# # NAS Module Demonstration

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
import flbs_ais.nas as nas

# %% [markdown]
# ---
# ## Search for a species
#
# The following code will take a species' scientific name and search the NAS database for any matching species. The purpose of this is to obtain a species ID, which is needed for further methods of this module. The first method, *species_search*, returns a list of python dictionaries, each of which contains a series of values related to that species. The second function, *species_string*, returns a string of that list in a readable form.

# %%
search_result = nas.species_search("Oncorhynchus", "mykiss");
search_string = nas.species_string(search_result);
print(search_string)
# Out:
# speciesID: 910
# itis_tsn: 161989
# group: Fishes
# family: Salmonidae
# genus: Oncorhynchus
# species: mykiss
# subspecies:
# variety:
# authority: (Walbaum, 1792)
# common_name: Rainbow Trout
# native_exotic: Native
# Fresh/Marine/Brackish: Freshwater-Marine
#
# speciesID: 911
# itis_tsn: 553422
# group: Fishes
# family: Salmonidae
# genus: Oncorhynchus
# species: mykiss
# subspecies: irideus
# variety:
# authority: (Gibbons, 1955)
# common_name: coastal rainbow trout
# native_exotic: Native
# Fresh/Marine/Brackish: Freshwater-Marine
#
# speciesID: 913
# itis_tsn: None
# group: Fishes
# family: Salmonidae
# genus: Oncorhynchus
# species: mykiss
# subspecies: kamloops strain
# variety:
# authority:
# common_name: Kamloops trout
# native_exotic: Native
# Fresh/Marine/Brackish: Freshwater-Marine
#
# speciesID: 914
# itis_tsn: None
# group: Fishes
# family: Salmonidae
# genus: Oncorhynchus
# species: mykiss
# subspecies: ssp.
# variety:
# authority:
# common_name: redband trout
# native_exotic: Native
# Fresh/Marine/Brackish: Freshwater-Marine

# %% [markdown]
# ---
# ## Get a pandas dataframe for a species id
#
# Once a species ID is known, the *getdf* method can be used to get a pandas dataframe containing all the occurrence data for that species in the NAS database. The columns parameter determines which of the columns should be kept in the dataframe. The limit parameter determines how many rows will be in the dataframe, with a value of -1 returning unlimited results. An API key is necessary to get more than 100 rows.
#
# To return a list of column names, use *get_header*. All column names are lower case with no spaces.

# %%
print("\nList of accepted column names for the keep_column parameter:\n")
name_list = nas.get_header()
for i, name in enumerate(name_list):
    if i:
        # Print a comma if this is not the first element
        print(', ', end='')
    # Print the column name after the comma
    print(name, end='')
print()

print("\n\nResults from an API query placed into a pandas dataframe:\n")
redband_trout_df = nas.getdf(914, keep_columns=None, limit=20, api_key=None)
redband_trout_df.head()
# Out:
# List of accepted column names for the keep_column parameter:
#
# specimennumber, speciesid, group, family, genus, species, scientificname, commonname, country, state, county, locality, decimallatitude, decimallongitude, latlongsource, latlongaccuracy, drainagename, centroidtype, huc8name, huc8, huc10name, huc10, huc12name, huc12, date, year, month, day, status, comments, recordtype, disposal, museumcatnumber, freshmarineintro, references
#
#
# Results from an API query placed into a pandas dataframe:
#    specimennumber  speciesid   group      family         genus species  \
# 0           43833        914  Fishes  Salmonidae  Oncorhynchus  mykiss
# 1           43834        914  Fishes  Salmonidae  Oncorhynchus  mykiss
# 2           43835        914  Fishes  Salmonidae  Oncorhynchus  mykiss
# 3          290383        914  Fishes  Salmonidae  Oncorhynchus  mykiss
# 4          290385        914  Fishes  Salmonidae  Oncorhynchus  mykiss
#
#         scientificname     commonname  country    state  ...  year month  \
# 0  Oncorhynchus mykiss  redband trout      NaN    Texas  ...  1983   NaN
# 1  Oncorhynchus mykiss  redband trout      NaN    Texas  ...  1986   NaN
# 2  Oncorhynchus mykiss  redband trout      NaN    Texas  ...  1992   NaN
# 3  Oncorhynchus mykiss  redband trout      NaN  Montana  ...  1982   8.0
# 4  Oncorhynchus mykiss  redband trout      NaN  Montana  ...  1982   9.0
#
#     day   status comments  recordtype  disposal museumcatnumber  \
# 0   NaN  stocked           Literature
# 1   NaN  stocked           Literature
# 2   NaN  unknown           Literature
# 3  19.0  stocked           Literature
# 4   8.0  stocked           Literature
#
#   freshmarineintro                                         references
# 0       Freshwater  [{'key': 360, 'refType': 'Report', 'year': 199...
# 1       Freshwater  [{'key': 360, 'refType': 'Report', 'year': 199...
# 2       Freshwater  [{'key': 360, 'refType': 'Report', 'year': 199...
# 3       Freshwater  [{'key': 24224, 'refType': 'Database', 'year':...
# 4       Freshwater  [{'key': 24224, 'refType': 'Database', 'year':...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Processing NAS CSV files into a pandas dataframe
#
# A CSV file containing similar data can be downloaded from the NAS website. However, its form is slightly different from the data that is pulled from an API request. The *process_csv_df* method converts such a CSV file into a pandas dataframe. Much like the *getdf* method, *process_csv_df* accepts a parameter for a list of column names to keep.
#
# This method does not require an API key parameter or a limit parameter as it simply processes a file that's already been downloaded.

# %%
print("\n\nResults from a CSV file placed into a pandas dataframe:\n")
nas_csv_df = nas.process_csv_df("../demo/NAS_data_914.csv", keep_columns=None)
nas_csv_df.head()
# Out:
# Results from a CSV file placed into a pandas dataframe:
#    specimennumber  speciesid   group      family  genus  species  \
# 0          292742        914  Fishes  Salmonidae    NaN      NaN
# 1          292709        914  Fishes  Salmonidae    NaN      NaN
# 2          292718        914  Fishes  Salmonidae    NaN      NaN
# 3          292735        914  Fishes  Salmonidae    NaN      NaN
# 4          292737        914  Fishes  Salmonidae    NaN      NaN
#
#              scientificname     commonname                   country state  \
# 0  Oncorhynchus mykiss ssp.  redband trout  United States of America    MT
# 1  Oncorhynchus mykiss ssp.  redband trout  United States of America    MT
# 2  Oncorhynchus mykiss ssp.  redband trout  United States of America    MT
# 3  Oncorhynchus mykiss ssp.  redband trout  United States of America    MT
# 4  Oncorhynchus mykiss ssp.  redband trout  United States of America    MT
#
#    ...  year month   day   status           comments  recordtype disposal  \
# 0  ...  1996   8.0  20.0  stocked                NaN  Literature      NaN
# 1  ...  2002   8.0  30.0  stocked                NaN  Literature      NaN
# 2  ...  2007   7.0  20.0  stocked                NaN  Literature      NaN
# 3  ...  1993   9.0   1.0  stocked  9/1/1993-9/2/1993  Literature      NaN
# 4  ...  1993   9.0   1.0  stocked                NaN  Literature      NaN
#
#    museumcatnumber  freshmarineintro  \
# 0              NaN        Freshwater
# 1              NaN        Freshwater
# 2              NaN        Freshwater
# 3              NaN        Freshwater
# 4              NaN        Freshwater
#
#                                           references
# 0  [{'key': 24224, 'type': 'Database', 'date': 20...
# 1  [{'key': 24224, 'type': 'Database', 'date': 20...
# 2  [{'key': 24224, 'type': 'Database', 'date': 20...
# 3  [{'key': 24224, 'type': 'Database', 'date': 20...
# 4  [{'key': 24224, 'type': 'Database', 'date': 20...
#
# [5 rows x 35 columns]

# %%
print(list(nas_csv_df.columns))
# Out:
# ['specimennumber', 'speciesid', 'group', 'family', 'genus', 'species', 'scientificname', 'commonname', 'country', 'state', 'county', 'locality', 'decimallatitude', 'decimallongitude', 'latlongsource', 'latlongaccuracy', 'drainagename', 'centroidtype', 'huc8name', 'huc8', 'huc10name', 'huc10', 'huc12name', 'huc12', 'date', 'year', 'month', 'day', 'status', 'comments', 'recordtype', 'disposal', 'museumcatnumber', 'freshmarineintro', 'references']
