# %% [markdown]
# # Hydrilla
# #### *Hydrilla verticillata*
# ---

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys

import numpy as np
import pandas as pd

import flbs_ais.nas as nas

# %% [markdown]
# #### Database Species Search Results
# NOTE: Enter scientific name in the following code block

# %%
search_result = nas.species_search('Hydrilla', 'verticillata')
search_string = nas.species_string(search_result)
print(search_string)
# Out:
# speciesID: 6
# itis_tsn: 38974
# group: Plants
# family: Hydrocharitaceae
# genus: Hydrilla
# species: verticillata
# subspecies:
# variety:
# authority: (L.f.) Royle
# common_name: hydrilla
# native_exotic: Exotic
# Fresh/Marine/Brackish: Freshwater

# %% [markdown]
# ---
# ## API Query Dataframe for Hydrilla
# Another error.

# %%
api_key = ""
with open("../tmp/api_key.txt", 'r') as file:
    api_key = file.readline()
api_df = nas.getdf(6, keep_columns=None, limit=1, api_key=api_key)
print(f"Results: {len(api_df)}")
api_df.head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-7-f4fbe2d3b104> in <module>
#       2 with open("../tmp/api_key.txt", 'r') as file:
#       3     api_key = file.readline()
# ----> 4 api_df = nas.getdf(6, keep_columns=None, limit=1, api_key=api_key)
#       5 print(f"Results: {len(api_df)}")
#       6 api_df.head()
#
# ~/workspace/flbs_ais/src/flbs_ais/nas.py in getdf(species_id, keep_columns, limit, api_key)
#      71     req = requests.get(url_request, params={'limit':limit})
#      72     req_parsed = re.sub(r'^jsonp\d+\(|\)\s+$', '', req.text)
# ---> 73     req_json = json.loads(req_parsed)
#      74     api_df = pd.json_normalize(req_json, 'results')
#      75
#
# ~/anaconda3/envs/flbs_ais/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/envs/flbs_ais/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/envs/flbs_ais/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ---
# ## Most Common References for API Query Dataframe

# %%
api_ref_count = nas.ref_counts(api_df)
print(nas.ref_string(api_ref_count, limit=20))

# %% [markdown]
# ---
# ## CSV File Dataframe for Hydrilla

# %%
csv_df = nas.process_csv_df("../tmp/NAS-Data-HydrillaVerticillata.csv")
print(f"Results: {len(csv_df)}")
csv_df.head()
# Out:
# Results: 10706
#    specimennumber  speciesid   group            family  genus  species  \
# 0         1523973          6  Plants  Hydrocharitaceae    NaN      NaN
# 1         1523972          6  Plants  Hydrocharitaceae    NaN      NaN
# 2         1633925          6  Plants  Hydrocharitaceae    NaN      NaN
# 3         1322352          6  Plants  Hydrocharitaceae    NaN      NaN
# 4         1633926          6  Plants  Hydrocharitaceae    NaN      NaN
#
#           scientificname commonname                   country state  ...  \
# 0  Hydrilla verticillata   hydrilla  United States of America    CT  ...
# 1  Hydrilla verticillata   hydrilla  United States of America    CT  ...
# 2  Hydrilla verticillata   hydrilla  United States of America    CT  ...
# 3  Hydrilla verticillata   hydrilla  United States of America    CT  ...
# 4  Hydrilla verticillata   hydrilla  United States of America    CT  ...
#
#    year month   day       status  \
# 0  2016   6.0   4.0  established
# 1  2016   6.0   4.0  established
# 2  2017   9.0   8.0  established
# 3  2016   9.0  19.0  established
# 4  2018  10.0   1.0  established
#
#                                             comments  recordtype  \
# 0                                                NaN  Literature
# 1                                                NaN  Literature
# 2                                                NaN    Specimen
# 3  Discovered in 2016, though likely present "in ...  Literature
# 4  Growing in silt in 1.0 meters of water. Found ...    Specimen
#
#                                       disposal       museumcatnumber  \
# 0                                          NaN               3377487
# 1                                          NaN               3377622
# 2  Connecticut Agricultural Experiment Station  HydVer00800009082017
# 3                                          NaN                   NaN
# 4  Connecticut Agricultural Experiment Station  HydVer01600010012018
#
#    freshmarineintro                                         references
# 0        Freshwater  [{'key': 25944, 'refType': 'Database', 'year':...
# 1        Freshwater  [{'key': 25944, 'refType': 'Database', 'year':...
# 2        Freshwater  [{'key': 34017, 'refType': 'Report', 'year': 2...
# 3        Freshwater  [{'key': 29080, 'refType': 'News', 'year': 201...
# 4        Freshwater  [{'key': 34017, 'refType': 'Report', 'year': 2...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Most Common References for CSV File Dataframe

# %%
csv_ref_count = nas.ref_counts(csv_df)
print(nas.ref_string(csv_ref_count, limit=20))
# Out:
# --------
# Most common reference 1
#
# Source number:      1
# Title:              Annual aquatic plant survey 1982-2017
# Author:             Florida Fish and Wildlife Conservation Commission, Invasive Plant Management Section.
# Publisher:          Florida Fish and Wildlife Conservation Commission
# Publisher Location: Tallahassee, FL
# Year:               2017
# Reference Type:     Database
#
# Total Occurrences:  6457
# --------
#
# --------
# Most common reference 2
#
# Total Occurrences:  2332
# --------
#
# --------
# Most common reference 3
#
# Source number:      1
# Title:              EDDMapS: Early detection and distribution mapping system
# Author:             Center for Invasive Species and Ecosystem Health.
# Publisher:          The University of Georgia
# Publisher Location: Tifton, GA
# Year:               2019
# Reference Type:     Database
#
# Total Occurrences:  242
# --------
#
# --------
# Most common reference 4
#
# Source number:      1
# Title:              Calflora
# Author:             West, R., J. Malpas, C. Powell, M. Tollett, D. Anderson, and E. Dorrington.
# Publisher:          nan
# Publisher Location: Berkeley, CA
# Year:               2019
# Reference Type:     Database
#
# Total Occurrences:  128
# --------
#
# --------
# Most common reference 5
#
# Source number:      1
# Title:              iNaturalist.org
# Author:             Ueda, K., J. Belmonte, A. Shepard, P. Leary, and S. Loarie.
# Publisher:          California Academy of Sciences
# Publisher Location: San Francisco, CA
# Year:               2019
# Reference Type:     Database
#
# Total Occurrences:  117
# --------
#
# --------
# Most common reference 6
#
# Source number:      1
# Title:              Texas Invasives Database
# Author:             Texas Invasive Plant and Pest Council.
# Publisher:          Lady Bird Johnson Wildflower Center
# Publisher Location: Austin, TX
# Year:               2018
# Reference Type:     Database
#
# Total Occurrences:  105
# --------
#
# --------
# Most common reference 7
#
# Source number:      1
# Title:              Invasive Plant Atlas of the MidSouth.
# Author:             Madsen, J.D.
# Publisher:          Geosystems Research Institute, Mississippi State University
# Publisher Location: Starkville, MS
# Year:               2010
# Reference Type:     Database
#
# Total Occurrences:  77
# --------
#
# --------
# Most common reference 8
#
# Source number:      1
# Title:              Economical and Environmental Impacts of N.C. Aquatic Weed Infestations.
# Author:             North Carolina Division of Water Resources.
# Publisher:          North Carolina Department of Environment, Health, and Natural Resources.
# Publisher Location: Raleigh, NC
# Year:               1996
# Reference Type:     Book
#
# Total Occurrences:  73
# --------
#
# --------
# Most common reference 9
#
# Source number:      1
# Title:              Statewide Aquatic Vegetation Survey Summary, 1995 Report.
# Author:             Helton, R.J., and L.H. Hartmann.
# Publisher:          Inland Fisheries Division, District 3-E, Jasper, Texas.
# Publisher Location: nan
# Year:               1996
# Reference Type:     Report
#
# Total Occurrences:  58
# --------
#
# --------
# Most common reference 10
#
# Source number:      1
# Title:              Joint Aquatic Invasive Species Survey, 2010
# Author:             Central Hardwoods Invasive Plant Network.
# Publisher:          University of Georgia
# Publisher Location: Athens, GA
# Year:               2010
# Reference Type:     Database
#
# Total Occurrences:  34
# --------
#
# --------
# Most common reference 11
#
# Source number:      1
# Title:              Calflora
# Author:             West, R., J. Malpas, C. Powell, M. Tollett, D. Anderson, and E. Dorrington.
# Publisher:          nan
# Publisher Location: Berkeley, CA
# Year:               2019
# Reference Type:     Database
#
# Source number:      2
# Title:              Consortium of California Herbaria (CCH)
# Author:             Alexander, J., S. Markos, J. Yost, R.L. Moe, E. Dean, and M. Nazaire.
# Publisher:          Regents of the University of California
# Publisher Location: nan
# Year:               2016
# Reference Type:     Database
#
# Total Occurrences:  32
# --------
#
# --------
# Most common reference 12
#
# Source number:      1
# Title:              Major public lakes of Louisiana with Hydrilla.
# Author:             Louisiana Department of Wildlife and Fisheries, Inland Fish Division.
# Publisher:          unpublished map prepared for in-office use.
# Publisher Location: nan
# Year:               1998
# Reference Type:     Report
#
# Total Occurrences:  31
# --------
#
# --------
# Most common reference 13
#
# Source number:      1
# Title:              Draft 2017 Annual South Carolina Aquatic Plant Management Plan - Part II
# Author:             Aquatic Nuisance Species Program.
# Publisher:          South Carolina Department of Natural Resources
# Publisher Location: Columbia, SC
# Year:               2017
# Reference Type:     Report
#
# Total Occurrences:  31
# --------
#
# --------
# Most common reference 14
#
# Source number:      1
# Title:              Maryland Aquatic Nuisance Species Management Plan.
# Author:             Maryland Department of Natural Resources.
# Publisher:          Maryland Department of Natural Resources
# Publisher Location: Annapolis, MD
# Year:               2016
# Reference Type:     Report
#
# Total Occurrences:  26
# --------
#
# --------
# Most common reference 15
#
# Source number:      1
# Title:              NYS Exotic Aquatic Plant Locations 2015
# Author:             Kishbaugh, S.A.
# Publisher:          New York State Department of Environmental Conservation
# Publisher Location: Albany, NY
# Year:               2015
# Reference Type:     Database
#
# Total Occurrences:  21
# --------
#
# --------
# Most common reference 16
#
# Source number:      1
# Title:              Environmental DNA detection of aquatic invasive plants in lab mesocosm and natural field conditions
# Author:             Gantz, C.A., M.A. Renshaw, D. Erickson, D.M. Lodge, and S.P. Egan.
# Publisher:          nan
# Publisher Location: nan
# Year:               2018
# Reference Type:     Journal Article
#
# Total Occurrences:  19
# --------
#
# --------
# Most common reference 17
#
# Source number:      1
# Title:              University of Tennessee Herbarium (TENN)
# Author:             Wofford, B.E. (curator), Q.V. Ma (manager), and W.M. Dennis.
# Publisher:          University of Tennessee
# Publisher Location: Knoxville, TN
# Year:               2016
# Reference Type:     Database
#
# Total Occurrences:  16
# --------
#
# --------
# Most common reference 18
#
# Source number:      1
# Title:              Distribution of Hydrilla and Giant Salvinia in Mississippi in 2005.
# Author:             Madsen, J.D, R.M. Wersal, and W. Robles.
# Publisher:          Geosystems Research Institute
# Publisher Location: Mississippi State, MS
# Year:               2006
# Reference Type:     Report
#
# Total Occurrences:  15
# --------
#
# --------
# Most common reference 19
#
# Source number:      1
# Title:              Aquatic plant survey for <em>Hydrilla verticillata</em>, <em>Hydrocharis morsus-ranae</em>, and <em>Nymphoides peltata</em>
# Author:             Cleveland Metroparks
# Publisher:          Cleveland Metroparks
# Publisher Location: Cleveland, OH
# Year:               2019
# Reference Type:     Database
#
# Total Occurrences:  15
# --------
#
# --------
# Most common reference 20
#
# Source number:      1
# Title:              Herbarium Specimen Voucher Data,
# Author:             North Carolina State University Herbarium (NCSC).
# Publisher:          North Carolina State University
# Publisher Location: Raleigh, NC
# Year:               2009
# Reference Type:     Database
#
# Total Occurrences:  14
# --------
