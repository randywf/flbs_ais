# %% [markdown]
# # Monoecious Hydrilla
# #### *Hydrilla verticillata [monoecious]*
# ---

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

import numpy as np
import pandas as pd

import flbs_ais.nas as nas

# %% [markdown]
# #### Database Species Search Results

# %%
search_result = nas.species_search('Hydrilla', '')
search_string = nas.species_string(search_result)
print(search_string)
# Out:
# speciesID: 6
# itis_tsn: 38974
# group: Plants
# family: Hydrocharitaceae
# genus: Hydrilla
# species: verticillata
# subspecies:
# variety:
# authority: (L.f.) Royle
# common_name: hydrilla
# native_exotic: Exotic
# Fresh/Marine/Brackish: Freshwater
#
# speciesID: 2942
# itis_tsn: 38974
# group: Plants
# family: Hydrocharitaceae
# genus: Hydrilla
# species: verticillata [dioecious]
# subspecies:
# variety:
# authority: (L. f.) Royle
# common_name: dioecious hydrilla
# native_exotic: Exotic
# Fresh/Marine/Brackish: Freshwater
#
# speciesID: 2943
# itis_tsn: 38974
# group: Plants
# family: Hydrocharitaceae
# genus: Hydrilla
# species: verticillata [monoecious]
# subspecies:
# variety:
# authority: (L. f.) Royle
# common_name: monoecious hydrilla
# native_exotic: Exotic
# Fresh/Marine/Brackish: Freshwater

# %% [markdown]
# ---
# ## API Query Dataframe for Monoecious Hydrilla

# %%
api_key = ""
with open("../tmp/api_key.txt", 'r') as file:
    api_key = file.readline()
api_df = nas.getdf(2943, keep_columns=None, limit=-1, api_key=api_key)
print(f"Results: {len(api_df)}")
api_df.head()
# Out:
# Results: 672
#    specimennumber  speciesid   group            family     genus  \
# 0          213316       2943  Plants  Hydrocharitaceae  Hydrilla
# 1          213681       2943  Plants  Hydrocharitaceae  Hydrilla
# 2          213682       2943  Plants  Hydrocharitaceae  Hydrilla
# 3          213683       2943  Plants  Hydrocharitaceae  Hydrilla
# 4          213684       2943  Plants  Hydrocharitaceae  Hydrilla
#
#                      species                      scientificname  \
# 0  verticillata [monoecious]  Hydrilla verticillata [monoecious]
# 1  verticillata [monoecious]  Hydrilla verticillata [monoecious]
# 2  verticillata [monoecious]  Hydrilla verticillata [monoecious]
# 3  verticillata [monoecious]  Hydrilla verticillata [monoecious]
# 4  verticillata [monoecious]  Hydrilla verticillata [monoecious]
#
#             commonname  country       state  ...  year month  day  \
# 0  monoecious hydrilla      NaN  Washington  ...  1995     5   20
# 1  monoecious hydrilla      NaN    Virginia  ...  1990     5   20
# 2  monoecious hydrilla      NaN    Maryland  ...  1990     5   20
# 3  monoecious hydrilla      NaN    Virginia  ...  1991     2    2
# 4  monoecious hydrilla      NaN    Virginia  ...  1991     2    2
#
#         status                comments  recordtype  disposal  \
# 0   eradicated  Established until 2011  Literature
# 1  established                          Literature
# 2  established                          Literature
# 3  established                          Literature
# 4  established                          Literature
#
#         museumcatnumber freshmarineintro  \
# 0  herb/King Cty Sur Wa       Freshwater
# 1                             Freshwater
# 2                             Freshwater
# 3                             Freshwater
# 4                             Freshwater
#
#                                           references
# 0  [{'key': 10194, 'refType': 'Journal Article', ...
# 1  [{'key': 10100, 'refType': 'Other', 'year': 19...
# 2  [{'key': 10100, 'refType': 'Other', 'year': 19...
# 3  [{'key': 10100, 'refType': 'Other', 'year': 19...
# 4  [{'key': 10100, 'refType': 'Other', 'year': 19...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Most Common References for API Query Dataframe

# %%
api_ref_count = nas.ref_counts(api_df)
print(nas.ref_string(api_ref_count, limit=5))
# Out:
# --------
# Most common reference 1
#
# Total Occurrences:  85
# --------
#
# --------
# Most common reference 2
#
# Source number:      1
# Title:              Economical and Environmental Impacts of N.C. Aquatic Weed Infestations.
# Author:             North Carolina Division of Water Resources.
# Publisher:          North Carolina Department of Environment, Health, and Natural Resources.
# Publisher Location: Raleigh, NC
# Year:               1996
# Reference Type:     Book
#
# Total Occurrences:  60
# --------
#
# --------
# Most common reference 3
#
# Source number:      1
# Title:              Calflora
# Author:             West, R., J. Malpas, C. Powell, M. Tollett, D. Anderson, and E. Dorrington.
# Publisher:
# Publisher Location: Berkeley, CA
# Year:               2019
# Reference Type:     Database
#
# Total Occurrences:  57
# --------
#
# --------
# Most common reference 4
#
# Source number:      1
# Title:              Joint Aquatic Invasive Species Survey, 2010
# Author:             Central Hardwoods Invasive Plant Network.
# Publisher:          University of Georgia
# Publisher Location: Athens, GA
# Year:               2010
# Reference Type:     Database
#
# Total Occurrences:  34
# --------
#
# --------
# Most common reference 5
#
# Source number:      1
# Title:              EDDMapS: Early detection and distribution mapping system
# Author:             Center for Invasive Species and Ecosystem Health.
# Publisher:          The University of Georgia
# Publisher Location: Tifton, GA
# Year:               2019
# Reference Type:     Database
#
# Total Occurrences:  29
# --------

# %% [markdown]
# ---
# ## CSV File Dataframe for Monoecious Hydrilla

# %%
csv_df = nas.process_csv_df("../tmp/NAS-Data-MonoeciousHydrilla.csv")
print(f"Results: {len(csv_df)}")
csv_df.head()
# Out:
# Results: 687
#    specimennumber  speciesid   group            family  genus  species  \
# 0         1401618       2943  Plants  Hydrocharitaceae    NaN      NaN
# 1         1467122       2943  Plants  Hydrocharitaceae    NaN      NaN
# 2         1401616       2943  Plants  Hydrocharitaceae    NaN      NaN
# 3         1633965       2943  Plants  Hydrocharitaceae    NaN      NaN
# 4         1633966       2943  Plants  Hydrocharitaceae    NaN      NaN
#
#                        scientificname           commonname  \
# 0  Hydrilla verticillata [monoecious]  monoecious hydrilla
# 1  Hydrilla verticillata [monoecious]  monoecious hydrilla
# 2  Hydrilla verticillata [monoecious]  monoecious hydrilla
# 3  Hydrilla verticillata [monoecious]  monoecious hydrilla
# 4  Hydrilla verticillata [monoecious]  monoecious hydrilla
#
#                     country state  ...  year month   day       status  \
# 0  United States of America    AL  ...  2015   9.0   8.0  established
# 1  United States of America    AL  ...  2018   7.0   5.0  established
# 2  United States of America    AL  ...  2007   9.0  27.0  established
# 3  United States of America    AR  ...  2005   8.0   3.0  established
# 4  United States of America    AR  ...  2005   8.0   3.0  established
#
#                                             comments  recordtype disposal  \
# 0                                                NaN    Specimen     UWAL
# 1  <a href=https://www.inaturalist.org/observatio...  Literature      NaN
# 2                                                NaN    Specimen     TENN
# 3  Genotyped as monoecious by Dean Williams (Texa...    Specimen     UARK
# 4  Genotyped as monoecious by Dean Williams (Texa...    Specimen     UARK
#
#    museumcatnumber  freshmarineintro  \
# 0            30274        Freshwater
# 1         14078242        Freshwater
# 2            14523        Freshwater
# 3            48098        Freshwater
# 4            48099        Freshwater
#
#                                           references
# 0  [{'key': 28852, 'refType': 'Database', 'year':...
# 1  [{'key': 25944, 'refType': 'Database', 'year':...
# 2  [{'key': 28843, 'refType': 'Database', 'year':...
# 3  [{'key': 29018, 'refType': 'Database', 'year':...
# 4  [{'key': 29018, 'refType': 'Database', 'year':...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Most Common References for CSV File Dataframe
# NOTE: Reference information for CSV files is not currently functional

# %%
#csv_ref_count = nas.ref_counts(csv_df)
#print(nas.ref_string(csv_ref_count, limit=20))
