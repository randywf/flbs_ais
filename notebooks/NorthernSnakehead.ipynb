# %% [markdown]
# # Northern Snakehead
# #### *Channa argus*
# ---

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

import numpy as np
import pandas as pd

import flbs_ais.nas as nas

# %% [markdown]
# #### Database Species Search Results

# %%
search_result = nas.species_search('Channa', 'argus')
search_string = nas.species_string(search_result)
print(search_string)
# Out:
# speciesID: 2265
# itis_tsn: 166680
# group: Fishes
# family: Channidae
# genus: Channa
# species: argus
# subspecies:
# variety:
# authority: (Cantor, 1842)
# common_name: Northern Snakehead
# native_exotic: Exotic
# Fresh/Marine/Brackish: Freshwater

# %% [markdown]
# ---
# ## API Query Dataframe for Northern Snakehead

# %%
api_key = ""
with open("../tmp/api_key.txt", 'r') as file:
    api_key = file.readline()
api_df = nas.getdf(2265, keep_columns=None, limit=-1, api_key=api_key)
print(f"Results: {len(api_df)}")
api_df.head()
# Out:
# Results: 4809
#    specimennumber  speciesid   group     family   genus species  \
# 0          154432       2265  Fishes  Channidae  Channa   argus
# 1          156785       2265  Fishes  Channidae  Channa   argus
# 2          156786       2265  Fishes  Channidae  Channa   argus
# 3          156787       2265  Fishes  Channidae  Channa   argus
# 4          156788       2265  Fishes  Channidae  Channa   argus
#
#   scientificname          commonname  country          state  ...  year month  \
# 0   Channa argus  Northern Snakehead      NaN  Massachusetts  ...  2001    10
# 1   Channa argus  Northern Snakehead      NaN       Maryland  ...  2002     5
# 2   Channa argus  Northern Snakehead      NaN       Maryland  ...  2002     6
# 3   Channa argus  Northern Snakehead      NaN       Maryland  ...  2002     7
# 4   Channa argus  Northern Snakehead      NaN       Maryland  ...  2002     7
#
#    day      status                                      comments  recordtype  \
# 0    4      failed  Data from GBIF data index - original values.    Specimen
# 1   18  eradicated                                                Literature
# 2   30  eradicated                                      2 annuli  Literature
# 3    8  eradicated                                                Literature
# 4   11  eradicated                                                Literature
#
#                                             disposal museumcatnumber  \
# 0  Museum of Comparative Zoology specimen collection      MCZ 160176
# 1                                           released
# 2
# 3
# 4
#
#   freshmarineintro                                         references
# 0       Freshwater  [{'key': 26212, 'refType': 'Database', 'year':...
# 1       Freshwater  [{'key': 13329, 'refType': 'Report', 'year': 2...
# 2       Freshwater  [{'key': 13329, 'refType': 'Report', 'year': 2...
# 3       Freshwater  [{'key': 13329, 'refType': 'Report', 'year': 2...
# 4       Freshwater  [{'key': 13490, 'refType': 'Report', 'year': 2...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Most Common References for API Query Dataframe

# %%
api_ref_count = nas.ref_counts(api_df)
print(nas.ref_string(api_ref_count, limit=5))
# Out:
# --------
# Most common reference 1
#
# Source number:      1
# Title:              Northern snakehead tagging study data in the Potomac River, 2009-2012 (unpublished data).
# Author:             Newhard, J.
# Publisher:          U.S. Fish and Wildlife Service
# Publisher Location: Annapolis, MD
# Year:               2012
# Reference Type:     Database
#
# Total Occurrences:  1129
# --------
#
# --------
# Most common reference 2
#
# Source number:      1
# Title:              Northern Snakehead <em>(Channa argus)</em> data (2007-2013) from the Potomac and Anacostia rivers in the District of Columbia (unpublished).
# Author:             Lyon, Luke.
# Publisher:          District Department of the Environment
# Publisher Location: Washington, DC
# Year:               2014
# Reference Type:     Database
#
# Total Occurrences:  804
# --------
#
# --------
# Most common reference 3
#
# Source number:      1
# Title:              A GIS approach for suitable habitat and population size of northern snakehead, an invasive fish
# Author:             Love, J.W., J.J. Newhard, and B. Greenfield
# Publisher:
# Publisher Location:
# Year:               2015
# Reference Type:     Journal Article
#
# Total Occurrences:  701
# --------
#
# --------
# Most common reference 4
#
# Source number:      1
# Title:              Northern Snakehead Master Dataset from tracking study.
# Author:             Lapointe, N.
# Publisher:
# Publisher Location:
# Year:               2014
# Reference Type:     Database
#
# Total Occurrences:  582
# --------
#
# --------
# Most common reference 5
#
# Source number:      1
# Title:
# Author:             Horodysky, K.
# Publisher:          Commonwealth of Virginia Department of Game and Inland Fisheries.
# Publisher Location: Henrico, VA
# Year:               2017
# Reference Type:     Database
#
# Total Occurrences:  539
# --------

# %% [markdown]
# ---
# ## CSV File Dataframe for Northern Snakehead

# %%
csv_df = nas.process_csv_df("../tmp/NAS-Data-NorthernSnakehead.csv")
print(f"Results: {len(csv_df)}")
csv_df.head()
# Out:
# Results: 4809
#    specimennumber  speciesid   group     family  genus  species  \
# 0         1340410       2265  Fishes  Channidae    NaN      NaN
# 1         1469166       2265  Fishes  Channidae    NaN      NaN
# 2         1469169       2265  Fishes  Channidae    NaN      NaN
# 3         1469164       2265  Fishes  Channidae    NaN      NaN
# 4         1469137       2265  Fishes  Channidae    NaN      NaN
#
#   scientificname          commonname                   country state  ...  \
# 0   Channa argus  Northern Snakehead  United States of America    AR  ...
# 1   Channa argus  Northern Snakehead  United States of America    AR  ...
# 2   Channa argus  Northern Snakehead  United States of America    AR  ...
# 3   Channa argus  Northern Snakehead  United States of America    AR  ...
# 4   Channa argus  Northern Snakehead  United States of America    AR  ...
#
#    year month  day       status comments              recordtype disposal  \
# 0  2016   7.0  4.0  established      NaN  Personal communication      NaN
# 1  2017   3.0  3.0  established      NaN              Literature      NaN
# 2  2017   3.0  3.0  established      NaN              Literature      NaN
# 3  2017   3.0  3.0  established      NaN              Literature      NaN
# 4  2017   3.0  3.0  established      NaN              Literature      NaN
#
#    museumcatnumber  freshmarineintro  \
# 0              NaN        Freshwater
# 1              NaN        Freshwater
# 2              NaN        Freshwater
# 3              NaN        Freshwater
# 4              NaN        Freshwater
#
#                                           references
# 0  [{'key': 29620, 'refType': 'Database', 'year':...
# 1  [{'key': 32005, 'refType': 'Database', 'year':...
# 2  [{'key': 32005, 'refType': 'Database', 'year':...
# 3  [{'key': 32005, 'refType': 'Database', 'year':...
# 4  [{'key': 32005, 'refType': 'Database', 'year':...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Most Common References for CSV File Dataframe

# %%
csv_ref_count = nas.ref_counts(csv_df)
print(nas.ref_string(csv_ref_count, limit=5))
# Out:
# --------
# Most common reference 1
#
# Source number:      1
# Title:              Northern snakehead tagging study data in the Potomac River, 2009-2012 (unpublished data).
# Author:             Newhard, J.
# Publisher:          U.S. Fish and Wildlife Service
# Publisher Location: Annapolis, MD
# Year:               2012
# Reference Type:     Database
#
# Total Occurrences:  1129
# --------
#
# --------
# Most common reference 2
#
# Source number:      1
# Title:              Northern Snakehead <em>(Channa argus)</em> data (2007-2013) from the Potomac and Anacostia rivers in the District of Columbia (unpublished).
# Author:             Lyon, Luke.
# Publisher:          District Department of the Environment
# Publisher Location: Washington, DC
# Year:               2014
# Reference Type:     Database
#
# Total Occurrences:  804
# --------
#
# --------
# Most common reference 3
#
# Source number:      1
# Title:              A GIS approach for suitable habitat and population size of northern snakehead, an invasive fish
# Author:             Love, J.W., J.J. Newhard, and B. Greenfield
# Publisher:          nan
# Publisher Location: nan
# Year:               2015
# Reference Type:     Journal Article
#
# Total Occurrences:  701
# --------
#
# --------
# Most common reference 4
#
# Source number:      1
# Title:              Northern Snakehead Master Dataset from tracking study.
# Author:             Lapointe, N.
# Publisher:          nan
# Publisher Location: nan
# Year:               2014
# Reference Type:     Database
#
# Total Occurrences:  582
# --------
#
# --------
# Most common reference 5
#
# Source number:      1
# Title:              nan
# Author:             Horodysky, K.
# Publisher:          Commonwealth of Virginia Department of Game and Inland Fisheries.
# Publisher Location: Henrico, VA
# Year:               2017
# Reference Type:     Database
#
# Total Occurrences:  539
# --------
