# %% [markdown]
# # Quagga Mussel
# #### *Dreissena rostriformis bugensis*
# ---

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

import numpy as np
import pandas as pd

import flbs_ais.nas as nas

# %% [markdown]
# #### Database Species Search Results
# NOTE: Enter scientific name in the following code block
# This doesn't work as the NAS database uses three names here.

# %%
search_result = nas.species_search('', '')
search_string = nas.species_string(search_result)
print(search_string)

# %% [markdown]
# ---
# ## API Query Dataframe for [*species*]
# NOTE: Change the species ID in the following code block

# %%
api_key = ""
with open("../tmp/api_key.txt", 'r') as file:
    api_key = file.readline()
api_df = nas.getdf(95, keep_columns=None, limit=-1, api_key=api_key)
print(f"Results: {len(api_df)}")
api_df.head()
# Out:
# Results: 1305
#    specimennumber  speciesid              group        family      genus  \
# 0          116837         95  Mollusks-Bivalves  Dreissenidae  Dreissena
# 1          116844         95  Mollusks-Bivalves  Dreissenidae  Dreissena
# 2          116846         95  Mollusks-Bivalves  Dreissenidae  Dreissena
# 3          116848         95  Mollusks-Bivalves  Dreissenidae  Dreissena
# 4          116850         95  Mollusks-Bivalves  Dreissenidae  Dreissena
#
#         species          scientificname     commonname  country state  ...  \
# 0  rostriformis  Dreissena rostriformis  quagga mussel      NaN   ONT  ...
# 1  rostriformis  Dreissena rostriformis  quagga mussel      NaN   ONT  ...
# 2  rostriformis  Dreissena rostriformis  quagga mussel      NaN   ONT  ...
# 3  rostriformis  Dreissena rostriformis  quagga mussel      NaN   ONT  ...
# 4  rostriformis  Dreissena rostriformis  quagga mussel      NaN   ONT  ...
#
#    year month  day       status comments  recordtype  disposal  \
# 0  1992    12  NaN  established           Literature
# 1  1992    12  NaN  established           Literature
# 2  1992    12  NaN  established           Literature
# 3  1992    12  NaN  established           Literature
# 4  1992    12  NaN  established           Literature
#
#   museumcatnumber freshmarineintro  \
# 0                       Freshwater
# 1                       Freshwater
# 2                       Freshwater
# 3                       Freshwater
# 4                       Freshwater
#
#                                           references
# 0  [{'key': 26189, 'refType': 'Report', 'year': 1...
# 1  [{'key': 26189, 'refType': 'Report', 'year': 1...
# 2  [{'key': 26189, 'refType': 'Report', 'year': 1...
# 3  [{'key': 26189, 'refType': 'Report', 'year': 1...
# 4  [{'key': 26189, 'refType': 'Report', 'year': 1...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Most Common References for API Query Dataframe

# %%
api_ref_count = nas.ref_counts(api_df)
print(nas.ref_string(api_ref_count, limit=20))
# Out:
# --------
# Most common reference 1
#
# Source number:      1
# Title:              Invader invaded: population dynamics of zebra mussels&nbsp;(<em>Dreissena polymorpha</em>) and quagga mussels (<em>Dreissena&nbsp;rostriformis bugensis</em>) in polymictic Oneida Lake, NY, USA&nbsp;(1992&ndash;2013)
# Author:             Hetherington, A.L., L.G. Rudstam, R.L. Schneider, K.T. Holeck, C.W. Hotaling, J.E. Cooper, and J.R. Jackson
# Publisher:
# Publisher Location:
# Year:               2019
# Reference Type:     Journal Article
#
# Source number:      2
# Title:              Lakewide zebra and quagga mussel summary, Oneida Lake, New York, 1992 to present
# Author:             Rudstam, L.G.
# Publisher:          Knowledge Network for Biocomplexity
# Publisher Location:
# Year:               2019
# Reference Type:     Database
#
# Total Occurrences:  465
# --------
#
# --------
# Most common reference 2
#
# Total Occurrences:  328
# --------
#
# --------
# Most common reference 3
#
# Source number:      1
# Title:              Midwest Invasive Species Information Network (MISIN)
# Author:             Michigan State University Board of Trustees.
# Publisher:          Michigan State University. Department of Entomology - Applied Spatial Ecology and Technical Services Laboratory
# Publisher Location: East Lansing, MI
# Year:               2019
# Reference Type:     Database
#
# Source number:      2
# Title:              Illinois Database of Aquatic Non-native Species
# Author:             Loyola University Chicago
# Publisher:          GISIN
# Publisher Location: Fort Collins, CO
# Year:               2013
# Reference Type:     Database
#
# Total Occurrences:  75
# --------
#
# --------
# Most common reference 4
#
# Source number:      1
# Title:              Tech memo 164, Baldridge Unpub>
# Lake Michigan Dreissena Density Database 3 May 2016
# Author:             Baldridge, Ashley
# Publisher:          NOAA GLERL
# Publisher Location:
# Year:               2016
# Reference Type:     Database
#
# Source number:      2
# Title:              Lake-Wide Benthic Surveys in Lake Michigan in 1994-95, 2000, 2005, and 2010: Abundances of the Ampipod Diporeia Spp. and Abundances and Biomass of the Mussels Driessena Polymorpha and Dreissena Rostriformis Bugensis
# Author:             Nalepa, T.F.. D.L. Fanslow, G.A. Lang, K.Mabrey, and M.Rowe
# Publisher:
# Publisher Location:
# Year:               2014
# Reference Type:     Report
#
# Total Occurrences:  70
# --------
#
# --------
# Most common reference 5
#
# Source number:      1
# Title:              2012 Eastern Finger Lakes Benthic Aquatic Invertebrate Assessment (unpublished).
# Author:             Wunderlich, M.
# Publisher:
# Publisher Location:
# Year:               2012
# Reference Type:     Database
#
# Total Occurrences:  53
# --------
#
# --------
# Most common reference 6
#
# Source number:      1
# Title:              Quagga and zebra mussel locations in southern Lake Michigan.
# Author:             Nalepa, Thomas.
# Publisher:          NOAA-GLERL.
# Publisher Location:
# Year:               2003
# Reference Type:     Database
#
# Total Occurrences:  35
# --------
#
# --------
# Most common reference 7
#
# Source number:      1
# Title:              Colonization, ecology, and population structure of the quagga mussel (Bivalvia: Dreissenidae) in the lower Great Lakes.
# Author:             Mills, E.L., R.M. Dermott, E.F. Roseman, D Dustin, E. Mellina, D.B. Conn, and A.P. Spidle
# Publisher:
# Publisher Location:
# Year:               1993
# Reference Type:     Journal Article
#
# Total Occurrences:  32
# --------
#
# --------
# Most common reference 8
#
# Source number:      1
# Title:              Distribution of zebra mussels on Canadian navigation buoys on the Great Lakes and upper St. Lawrence River, December 1992.
# Author:             Wormington, A., C.A. Timmins, and R.M. Dermott.
# Publisher:          Fisheries and Oceans Canada
# Publisher Location: Burlington, Ontario
# Year:               1993
# Reference Type:     Report
#
# Total Occurrences:  31
# --------
#
# --------
# Most common reference 9
#
# Source number:      1
# Title:              Midwest Invasive Species Information Network (MISIN)
# Author:             Michigan State University Board of Trustees.
# Publisher:          Michigan State University. Department of Entomology - Applied Spatial Ecology and Technical Services Laboratory
# Publisher Location: East Lansing, MI
# Year:               2019
# Reference Type:     Database
#
# Total Occurrences:  26
# --------
#
# --------
# Most common reference 10
#
# Source number:      1
# Title:              Invasive Species Catch 2017
# Author:             Bowen, A.
# Publisher:          U.S. Fish and Wildlife Service
# Publisher Location: Alpena, MI
# Year:               2018
# Reference Type:     Database
#
# Total Occurrences:  23
# --------
#
# --------
# Most common reference 11
#
# Source number:      1
# Title:              Invasive Species Mapping in Michigan: Data Downloads.
# Author:             Great Lakes Information Network.
# Publisher:
# Publisher Location:
# Year:               2008
# Reference Type:     Database
#
# Total Occurrences:  18
# --------
#
# --------
# Most common reference 12
#
# Source number:      1
# Title:              Great Lakes Coastal Monitoring Project: inverts dataset (through 2013)
# Author:             Brady, V.
# Publisher:          Environmental Protection Agency, Great Lakes National Program Office
# Publisher Location: Chicago, IL
# Year:               2015
# Reference Type:     Database
#
# Total Occurrences:  13
# --------
#
# --------
# Most common reference 13
#
# Source number:      1
# Title:              OFAH Database All Species - 2009 Download.
# Author:             Ontario Federation of Anglers and Hunters.
# Publisher:
# Publisher Location:
# Year:               2009
# Reference Type:     Database
#
# Total Occurrences:  12
# --------
#
# --------
# Most common reference 14
#
# Source number:      1
# Title:              Seasonal and depth variations in gametogenesis and spawning of Dreissena polymorpha and Dreissena bugensis in eastern Lake Erie.
# Author:             Claxton, W.T., and G.L. Mackie
# Publisher:
# Publisher Location:
# Year:               1998
# Reference Type:     Journal Article
#
# Total Occurrences:  11
# --------
#
# --------
# Most common reference 15
#
# Source number:      1
# Title:              Biology and Management of Invasive Quagga and Zebra Mussels in the Western United States.
# Author:             Wong, W.H., and S.L. Gerstenberger (eds.)
# Publisher:          CRC Press
# Publisher Location: Boca Raton, FL
# Year:               2015
# Reference Type:     Book
#
# Total Occurrences:  11
# --------
#
# --------
# Most common reference 16
#
# Source number:      1
# Title:              First finding of the amphipod Echinogammarus ischnus and the mussel Dreissena bugensis in Lake Michigan.
# Author:             Nalepa, T.F., D.W. Schloesser, S.A. Pothoven, D.W. Hondorp, D.L. Fanslow, M.L. Tuchman, and G.W. Fleischer
# Publisher:
# Publisher Location:
# Year:               2001
# Reference Type:     Journal Article
#
# Total Occurrences:  9
# --------
#
# --------
# Most common reference 17
#
# Source number:      1
# Title:              Invasive species monitoring in the Lake Erie and Lake Huron, 2013-2016.
# Author:             Bowen, A.
# Publisher:          U.S. Fish and Wildlife Service
# Publisher Location: Alpena, MI
# Year:               2017
# Reference Type:     Database
#
# Total Occurrences:  8
# --------
#
# --------
# Most common reference 18
#
# Source number:      1
# Title:              Lakes and rivers with invasives species
# Author:             Wisconsin Department of Natural Resources (WI DNR).
# Publisher:          Wisconsin Department of Natural Resources
# Publisher Location: Madison, WI
# Year:               2017
# Reference Type:     Database
#
# Total Occurrences:  8
# --------
#
# --------
# Most common reference 19
#
# Source number:      1
# Title:              Occurrence of the quagga mussel (<em>Dreissena bugensis</em>) and the zebra mussel (<em>Dreissena polymorpha</em>) in the Upper Mississippi River system.
# Author:             Grigorovich, I.A., T.R. Angradi, and C.A. Stepien
# Publisher:
# Publisher Location:
# Year:               2008
# Reference Type:     Journal Article
#
# Total Occurrences:  8
# --------
#
# --------
# Most common reference 20
#
# Source number:      1
# Title:              Nonindigenous mollusks and amphipods in the upper Mississippi drainage.
# Author:             Angradi, T.R.
# Publisher:          US Environmental Protection Agency
# Publisher Location: Duluth, MN
# Year:               2018
# Reference Type:     Database
#
# Source number:      2
# Title:              Occurrence of the quagga mussel (<em>Dreissena bugensis</em>) and the zebra mussel (<em>Dreissena polymorpha</em>) in the Upper Mississippi River system.
# Author:             Grigorovich, I.A., T.R. Angradi, and C.A. Stepien
# Publisher:
# Publisher Location:
# Year:               2008
# Reference Type:     Journal Article
#
# Total Occurrences:  8
# --------

# %% [markdown]
# ---
# ## CSV File Dataframe for [*species*]
# NOTE: Edit the file path in the following code block

# %%
csv_df = nas.process_csv_df("../tmp/NAS-Data-QuaggaMussel.csv")
print(f"Results: {len(csv_df)}")
csv_df.head()
# Out:
# Results: 1305
#    specimennumber  speciesid              group        family  genus  species  \
# 0          116958         95  Mollusks-Bivalves  Dreissenidae    NaN      NaN
# 1          116954         95  Mollusks-Bivalves  Dreissenidae    NaN      NaN
# 2          116957         95  Mollusks-Bivalves  Dreissenidae    NaN      NaN
# 3          116955         95  Mollusks-Bivalves  Dreissenidae    NaN      NaN
# 4          116956         95  Mollusks-Bivalves  Dreissenidae    NaN      NaN
#
#                     scientificname     commonname country state  ...  year  \
# 0  Dreissena rostriformis bugensis  quagga mussel  Canada   ONT  ...  1991
# 1  Dreissena rostriformis bugensis  quagga mussel  Canada   ONT  ...  1991
# 2  Dreissena rostriformis bugensis  quagga mussel  Canada   ONT  ...  1991
# 3  Dreissena rostriformis bugensis  quagga mussel  Canada   ONT  ...  1991
# 4  Dreissena rostriformis bugensis  quagga mussel  Canada   ONT  ...  1991
#
#   month  day       status comments              recordtype disposal  \
# 0  12.0  NaN  established      NaN  Personal communication      NaN
# 1  12.0  NaN  established      NaN  Personal communication      NaN
# 2  12.0  NaN  established      NaN  Personal communication      NaN
# 3  12.0  NaN  established      NaN  Personal communication      NaN
# 4  12.0  NaN  established      NaN  Personal communication      NaN
#
#    museumcatnumber  freshmarineintro  \
# 0              NaN        Freshwater
# 1              NaN        Freshwater
# 2              NaN        Freshwater
# 3              NaN        Freshwater
# 4              NaN        Freshwater
#
#                                           references
# 0  [{'key': nan, 'refType': nan, 'year': nan, 'au...
# 1  [{'key': nan, 'refType': nan, 'year': nan, 'au...
# 2  [{'key': nan, 'refType': nan, 'year': nan, 'au...
# 3  [{'key': nan, 'refType': nan, 'year': nan, 'au...
# 4  [{'key': nan, 'refType': nan, 'year': nan, 'au...
#
# [5 rows x 35 columns]

# %% [markdown]
# ---
# ## Most Common References for CSV File Dataframe
# NOTE: Reference information for CSV files is not currently functional

# %%
#csv_ref_count = nas.ref_counts(csv_df)
#print(nas.ref_string(csv_ref_count, limit=20))
